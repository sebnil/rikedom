# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import sys
sys.path.append('..') # add parent directory to path
sys.path.append('../../zipline-test/') # add parent directory to path
from datetime import datetime
from helpers.security_loader import load_from_yahoo
import numpy as np
import pandas as pd
from IPython.display import display
from IPython.core.display import HTML
import logging
logging.basicConfig(level=logging.DEBUG)
import statsmodels.api as sm
from rikedom_algorithms.hp_filter import HodrickPrescottAlgorithm
from rikedom import simulator

# %%
today = datetime.today().date()
hp_algo = HodrickPrescottAlgorithm()
hp_algo.run_algorithm(['NCC-A.ST'], datetime(2014, 6, 2), datetime(today.year, today.month, today.day))
# Out:
#                           NCC-A.ST  worth
# Date
# 2014-06-02 00:00:00+00:00      NaN  10000
# 2014-06-03 00:00:00+00:00      NaN  10000
# 2014-06-04 00:00:00+00:00      NaN  10000
# 2014-06-05 00:00:00+00:00      NaN  10000
# 2014-06-06 00:00:00+00:00      NaN  10000
# 2014-06-09 00:00:00+00:00      NaN  10000
# 2014-06-10 00:00:00+00:00      NaN  10000
# 2014-06-11 00:00:00+00:00      NaN  10000
# 2014-06-12 00:00:00+00:00      NaN  10000
# 2014-06-13 00:00:00+00:00        0  10000
# 2014-06-16 00:00:00+00:00        0  10000
# 2014-06-17 00:00:00+00:00        0  10000
# 2014-06-18 00:00:00+00:00        0  10000
# 2014-06-19 00:00:00+00:00        0  10000
# 2014-06-20 00:00:00+00:00        0  10000
# 2014-06-23 00:00:00+00:00        0  10000
# 2014-06-24 00:00:00+00:00        0  10000
# 2014-06-25 00:00:00+00:00        0  10000
# 2014-06-26 00:00:00+00:00        0  10000
# 2014-06-27 00:00:00+00:00        0  10000
# 2014-06-30 00:00:00+00:00        0  10000
# 2014-07-01 00:00:00+00:00        0  10000
# 2014-07-02 00:00:00+00:00        0  10000
# 2014-07-03 00:00:00+00:00        0  10000
# 2014-07-04 00:00:00+00:00        0  10000
# 2014-07-07 00:00:00+00:00        0  10000
# 2014-07-08 00:00:00+00:00        0  10000
# 2014-07-09 00:00:00+00:00        0  10000
# 2014-07-10 00:00:00+00:00        0  10000
# 2014-07-11 00:00:00+00:00        0  10000
# ...                            ...    ...
# 2015-09-03 00:00:00+00:00        0  13692
# 2015-09-04 00:00:00+00:00        0  13692
# 2015-09-07 00:00:00+00:00        0  13692
# 2015-09-08 00:00:00+00:00        0  13692
# 2015-09-09 00:00:00+00:00        0  13692
# 2015-09-10 00:00:00+00:00        0  13692
# 2015-09-11 00:00:00+00:00        0  13692
# 2015-09-14 00:00:00+00:00        0  13692
# 2015-09-15 00:00:00+00:00        0  13692
# 2015-09-16 00:00:00+00:00        0  13692
# 2015-09-17 00:00:00+00:00        0  13692
# 2015-09-18 00:00:00+00:00        0  13692
# 2015-09-21 00:00:00+00:00        0  13692
# 2015-09-22 00:00:00+00:00        0  13692
# 2015-09-23 00:00:00+00:00        0  13692
# 2015-09-24 00:00:00+00:00        0  13692
# 2015-09-25 00:00:00+00:00        0  13692
# 2015-09-28 00:00:00+00:00        0  13692
# 2015-09-29 00:00:00+00:00        0  13692
# 2015-09-30 00:00:00+00:00        0  13692
# 2015-10-01 00:00:00+00:00        0  13692
# 2015-10-02 00:00:00+00:00        0  13692
# 2015-10-05 00:00:00+00:00      100  13692
# 2015-10-06 00:00:00+00:00      100  14151
# 2015-10-07 00:00:00+00:00      100  14043
# 2015-10-08 00:00:00+00:00      100  14063
# 2015-10-09 00:00:00+00:00      100  14639
# 2015-10-12 00:00:00+00:00      100  14581
# 2015-10-13 00:00:00+00:00      100  14170
# 2015-10-14 00:00:00+00:00      100  13848
#
# [358 rows x 2 columns]

# %%
hp_algo.recorder
#data
# Out:
#                           NCC-A.ST  worth
# Date
# 2014-06-02 00:00:00+00:00      NaN  10000
# 2014-06-03 00:00:00+00:00      NaN  10000
# 2014-06-04 00:00:00+00:00      NaN  10000
# 2014-06-05 00:00:00+00:00      NaN  10000
# 2014-06-06 00:00:00+00:00      NaN  10000
# 2014-06-09 00:00:00+00:00      NaN  10000
# 2014-06-10 00:00:00+00:00      NaN  10000
# 2014-06-11 00:00:00+00:00      NaN  10000
# 2014-06-12 00:00:00+00:00      NaN  10000
# 2014-06-13 00:00:00+00:00        0  10000
# 2014-06-16 00:00:00+00:00        0  10000
# 2014-06-17 00:00:00+00:00        0  10000
# 2014-06-18 00:00:00+00:00        0  10000
# 2014-06-19 00:00:00+00:00        0  10000
# 2014-06-20 00:00:00+00:00        0  10000
# 2014-06-23 00:00:00+00:00        0  10000
# 2014-06-24 00:00:00+00:00        0  10000
# 2014-06-25 00:00:00+00:00        0  10000
# 2014-06-26 00:00:00+00:00        0  10000
# 2014-06-27 00:00:00+00:00        0  10000
# 2014-06-30 00:00:00+00:00        0  10000
# 2014-07-01 00:00:00+00:00        0  10000
# 2014-07-02 00:00:00+00:00        0  10000
# 2014-07-03 00:00:00+00:00        0  10000
# 2014-07-04 00:00:00+00:00        0  10000
# 2014-07-07 00:00:00+00:00        0  10000
# 2014-07-08 00:00:00+00:00        0  10000
# 2014-07-09 00:00:00+00:00        0  10000
# 2014-07-10 00:00:00+00:00        0  10000
# 2014-07-11 00:00:00+00:00        0  10000
# ...                            ...    ...
# 2015-09-03 00:00:00+00:00        0  13692
# 2015-09-04 00:00:00+00:00        0  13692
# 2015-09-07 00:00:00+00:00        0  13692
# 2015-09-08 00:00:00+00:00        0  13692
# 2015-09-09 00:00:00+00:00        0  13692
# 2015-09-10 00:00:00+00:00        0  13692
# 2015-09-11 00:00:00+00:00        0  13692
# 2015-09-14 00:00:00+00:00        0  13692
# 2015-09-15 00:00:00+00:00        0  13692
# 2015-09-16 00:00:00+00:00        0  13692
# 2015-09-17 00:00:00+00:00        0  13692
# 2015-09-18 00:00:00+00:00        0  13692
# 2015-09-21 00:00:00+00:00        0  13692
# 2015-09-22 00:00:00+00:00        0  13692
# 2015-09-23 00:00:00+00:00        0  13692
# 2015-09-24 00:00:00+00:00        0  13692
# 2015-09-25 00:00:00+00:00        0  13692
# 2015-09-28 00:00:00+00:00        0  13692
# 2015-09-29 00:00:00+00:00        0  13692
# 2015-09-30 00:00:00+00:00        0  13692
# 2015-10-01 00:00:00+00:00        0  13692
# 2015-10-02 00:00:00+00:00        0  13692
# 2015-10-05 00:00:00+00:00      100  13692
# 2015-10-06 00:00:00+00:00      100  14151
# 2015-10-07 00:00:00+00:00      100  14043
# 2015-10-08 00:00:00+00:00      100  14063
# 2015-10-09 00:00:00+00:00      100  14639
# 2015-10-12 00:00:00+00:00      100  14581
# 2015-10-13 00:00:00+00:00      100  14170
# 2015-10-14 00:00:00+00:00      100  13848
#
# [358 rows x 2 columns]

# %%
fig = plt.figure(figsize=(14,10))

subplot_def = 310

security = hp_algo.interesting_stocks[0]

subplot_def += 1
ax = fig.add_subplot(subplot_def)
ax.set_ylabel('%', color='blue')
ax.plot(hp_algo.data.index, hp_algo.data[security] / hp_algo.data[security][0]*100-100, label=security)
ax.legend(loc='best')
ax.grid()
ax2 = ax.twinx()
ax2.plot(data.index, data[security], color='red')
ax2.set_ylabel('sek', color='red')

subplot_def += 1
ax = fig.add_subplot(subplot_def)
ax.plot(xhat.index, xhat[security], label='xhat')
ax.legend(loc='best')
ax.grid()
ax2 = ax.twinx()
ax2.plot(data.index, data[security], color='red')
ax2.set_ylabel('sek', color='red')


subplot_def += 1
ax = fig.add_subplot(subplot_def)
ax.plot(buy_sell_hold_signal.index, buy_sell_hold_signal['buy_sell_hold_signal'])
ax.set_ylim([-1, 2])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cc10a7d9b7f7> in <module>()
#       8 ax = fig.add_subplot(subplot_def)
#       9 ax.set_ylabel('%', color='blue')
# ---> 10 ax.plot(hp_algo.data.index, hp_algo.data[security]/data[security][0]*100-100, label=security)
#      11 ax.legend(loc='best')
#      12 ax.grid()
#
# NameError: name 'data' is not defined
